# %%
import numpy as np

# %%
arr = np.array([2,4,8,10,12])
print(arr)
# Out:
# [ 2  4  8 10 12]

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
arr1 = np.array([2,6,4,8,7,10,12])
arr1.
